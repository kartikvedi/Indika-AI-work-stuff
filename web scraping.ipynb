# %%
import requests
from bs4 import BeautifulSoup

# %%
URL = "https://www.medindia.net/glossary/medical-dictionary.asp?alpha=z"
r = requests.get(URL)

# %%
soup = BeautifulSoup(r.content, 'html5lib') # If this line causes an error, run 'pip install html5lib' or install html5lib
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-env="health-information" lang="en">
#  <head>
#   <title>
#    Medical Dictionary / Glossary  | Medindia
#   </title>
#   <meta content="An online medical glossary of medical terms and definitions related to over 700 diseases, conditions and surgical procedures " name="Description"/>
#   <meta content="Medical glossary, medical dictionary, medical terms, medical definitions, diseases, health conditions, surgical procedures, Medical Acronyms, medical syndromes, Medical Meumonics, Medical Aphorism,  Medical Quotations,  Ayurveda recipes glossary, medindia" name="Keywords"/>
#   <link href="https://www.medindia.net/glossary/medical-dictionary.asp?alpha=Z" rel="canonical"/>
#   <!--include file = "../dfp/ros/header.asp"-->
#   <link href="https://hi.medindia.net/glossary/medical-dictionary.asp" hreflang="hi" rel="alternate"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# ...

# %%
# a = soup.select('div.wysiwyg-content p strong')
# a 
a=soup.select('a b') 
a
# Out:
# [<b>ZA-ZC</b>,
#  <b>ZD-ZJ</b>,
#  <b>ZK-ZM</b>,
#  <b>ZN</b>,
#  <b>ZO-ZS</b>,
#  <b>ZT-ZZ</b>]

# %%
names = [name.text for name in a]
names[6:]
# Out:
# []

# %%
from PyPDF2 import PdfFileReader
import requests
import io
from bs4 import BeautifulSoup

url=requests.get('https://chicago.medicine.uic.edu/wp-content/uploads/sites/6/2017/06/ophthalmic-dictionary_alphabetical_2011.pdf')
soup = BeautifulSoup(url.content,"lxml")

for a in soup.find_all('a', href=True):
    mystr= a['href']
    if(mystr[-4:]=='.pdf'):
        print ("url with pdf final:", a['href'])
        urlpdf = a['href']
        response = requests.get(urlpdf)
        with io.BytesIO(response.content) as f:
            pdf = PdfFileReader(f)
            information = pdf.getDocumentInfo()
            number_of_pages = pdf.getNumPages()
            txt = f"""
            Author: {information.author}
            Creator: {information.creator}
            Producer: {information.producer}
            Subject: {information.subject}
            Title: {information.title}
            Number of pages: {number_of_pages}
            """
            # Here the metadata of your pdf
            print(txt)
            # numpage for the number page
            numpage=6
            page = pdf.getPage(numpage)
            page_content = page.extractText()
            # print the content in the page 20            
            print(page_content)
